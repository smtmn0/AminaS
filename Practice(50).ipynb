# %% [markdown]
# <a href="https://colab.research.google.com/github/smtmn0/AminaS/blob/main/Practice(50).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практикалық тапсырмалар: Python негіздері

# %% [markdown]
# ## 1.Негізгі функциялар
#
# | Функция / Кілт сөз | Сипаттамасы (Қазақша) | Мысал (Python) |
# |---|---|---|
# | `print()` | Экранға мәтін, айнымалы немесе нәтиже шығарады | `print("Hello, World!")` |
# | `type()` | Мәннің немесе айнымалының деректер типін анықтайды | `print(type(x))` |
# | `#` | Бір жолдық комментарий жазу үшін қолданылады (оқылмайды) | `# Бұл түсіндірме мәтін` |
# | `len()` | Мәтіннің немесе тізімнің ұзындығын санайды | `len("Python") # Нәтиже: 6` |
#
# ## 2. Деректер типтері және Түрлендіру (Data Types & Casting)
#
# | Функция | Сипаттамасы (Қазақша) | Мысал (Python) |
# |---|---|---|
# | `int()` | Бөлшек санды немесе мәтінді бүтін санға айналдырады | `int(3.14) # Нәтиже: 3` |
# | `float()` | Бүтін санды немесе мәтінді бөлшек санға айналдырады | `float(5) # Нәтиже: 5.0` |
# | `str()` | Кез келген деректер типін мәтінге (жолға) айналдырады | `str(2024) # Нәтиже: "2024"` |
# | `bool()` | Мәнді логикалық типке (True/False) айналдырады | `bool(1) # Нәтиже: True` |
#
# ## 3. Мәтіндермен жұмыс істеу әдістері (String Methods)
#
#
# | Әдіс / Синтаксис | Сипаттамасы (Қазақша) | Мысал (Python) |
# |---|---|---|
# | `[ : ]` | Мәтіннің белгілі бір бөлігін кесіп алу (Slicing) | `"Apple"[0:3] # Нәтиже: "App"` |
# | `.upper()` | Мәтіндегі барлық әріптерді бас әріпке айналдырады | `"hi".upper() # Нәтиже: "HI"` |
# | `.lower()` | Мәтіндегі барлық әріптерді кіші әріпке айналдырады | `"HI".lower() # Нәтиже: "hi"` |
# | `.strip()` | Мәтіннің басы мен соңындағы бос орындарды алып тастайды | `" a ".strip() # Нәтиже: "a"` |
# | `.replace(a, b)` | Мәтіндегі бір таңбаны не сөзді екіншісіне ауыстырады | `"Cat".replace("C", "B")` |
# | `.split()` | Мәтінді көрсетілген белгі бойынша бөліп, тізім жасайды | `"a,b".split(",") # ['a', 'b']` |
# | `.count()` | Мәтін ішінде белгілі бір әріптің/сөздің неше рет кездесетінін санайды | `"banana".count("a") # 3` |
# | `f"..."` | Айнымалыларды мәтін ішіне тікелей енгізуге мүмкіндік береді | `f"My age is {age}"` |
#
# ## 4. Математикалық және Логикалық операторлар (Operators & Booleans)
#
# | Оператор | Сипаттамасы (Қазақша) | Мысал (Python) |
# |---|---|---|
# | `+`, `-`, `*`, `/` | Қосу, алу, көбейту, бөлу | `10 / 2 # Нәтиже: 5.0` |
# | `**` | Дәрежеге шығару | `3 ** 2 # Нәтиже: 9` |
# | `//` | Бүтін бөлу (бөлшек бөлігін алып тастайды) | `10 // 3 # Нәтиже: 3` |
# | `%` | Бөлуден қалған қалдықты табу (жұп/тақ тексеруге ыңғайлы) | `10 % 3 # Нәтиже: 1` |
# | `==`, `!=` | Тең бе? / Тең емес пе? | `5 == 5 # True` |
# | `>`, `<`, `>=`, `<=` | Үлкен, кіші, үлкен немесе тең, кіші немесе тең | `10 >= 8 # True` |
# | `and` | Екі шарт та Ақиқат (True) болса ғана орындалады | `x > 0 and x < 10` |
# | `or` | Шарттардың біреуі Ақиқат (True) болса жеткілікті | `x == 5 or x == 10` |
# | `not` | Логикалық мәнді керісінше өзгертеді (True-ды False-қа) | `not True # Нәтиже: False` |
#
# ## 5. Шартты операторлар (Conditions)
#
# | Кілт сөз | Сипаттамасы (Қазақша) | Құрылымы (Мысал) |
# |---|---|---|
# | `if` | Егер берілген шарт дұрыс (True) болса, төмендегі код орындалады. | `if x > 0: print("Оң сан")` |
# | `elif` | (Else if). Алдыңғы if шарты қате болса, келесі жаңа шартты тексереді. | `elif x == 0: print("Нөл")` |
# | `else` | Жоғарыдағы шарттардың ешқайсысы орындалмаған жағдайда жұмыс істейді. | `else: print("Теріс сан")` |

# %% [markdown]
# ## 1-бөлім: Шығару, Комментарийлер және Айнымалылар (1-10 тапсырмалар)
#
# Бұл бөлімде біз `print()` функциясын, айнымалыларды құруды және дұрыс атауды жаттықтырамыз.

# %%
# 1-тапсырма: Экранға "Hello, World!" мәтінін шығарыңыз.
print("Hello, World!")
# Out:
# Hello, World!

# %%
# 2-тапсырма: Өз атыңызды экранға шығаратын код жазыңыз.
print("Amina")
# Out:
# Amina

# %%
# 3-тапсырма: Осы қатардың алдына бір жолдық комментарий жазып, оны түсіндіріңіз.
#

# %%
# 4-тапсырма: `country` деген айнымалы құрып, оған "Kazakhstan" мәнін беріңіз. Содан кейін оны экранға шығарыңыз.
country = "Kazakhstan"
print(country)
# Out:
# Kazakhstan

# %%
# 5-тапсырма: `x` айнымалысына 10, `y` айнымалысына 20 мәнін беріп, олардың қосындысын шығарыңыз.
x = 10
y = 20
print(x+y)
# Out:
# 30

# %%
# 6-тапсырма: Бір қатарда a, b, c айнымалыларына тиісінше 1, 2, 3 мәндерін тағайындаңыз.
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
from typing import LiteralString
# 7-тапсырма: `first_name` және `last_name` айнымалыларын құрып, оларды бір `print()` ішінде шығарыңыз.
first_name = "Amina"
last_name = "Samatkyzy"
print (first_name, last_name)
# Out:
# Amina Samatkyzy

# %%
# 8-тапсырма: Айнымалыны жаңарту. `score = 50` деп беріңіз, сосын келесі қатарда оны 100-ге өзгертіп, шығарыңыз.
score = 100
print(score)
# Out:
# 100

# %%
# 9-тапсырма: Төмендегі кодтағы шегініс (indentation) қатесін түзеңіз:
#if 5 > 2:
#print("Дұрыс!")
if 5 > 2:
  print ("Correct!")
# Out:
# Correct!

# %%
# 10-тапсырма: Екі айнымалының мәнін ауыстырыңыз: a = 5, b = 10. (Кеңес: a, b = b, a)

# %% [markdown]
# ## 2-бөлім: Деректер типтері және Сандар (11-25 тапсырмалар)
#
# Python-дағы негізгі типтерді (`int`, `float`, `str`, `bool`) және математикалық амалдарды қолданамыз.

# %%
# 11-тапсырма: `year = 2024` айнымалысын құрып, оның типін `type()` арқылы шығарыңыз.
year = 2024
print (type(year))
# Out:
# <class 'int'>

# %%
# 12-тапсырма: `pi = 3.14` айнымалысының типін тексеріп шығарыңыз.
pi = 3.14
print (type(pi))
# Out:
# <class 'float'>

# %%
# 13-тапсырма: `is_active = True` айнымалысының типін тексеріңіз.
is_active = True
print(type(is_active))
# Out:
# <class 'bool'>

# %%
# 14-тапсырма: `7.89` бөлшек санын `int()` арқылы бүтін санға түрлендіріп шығарыңыз.
print(int(7.89))
# Out:
# 7

# %%
# 15-тапсырма: `15` бүтін санын `float()` арқылы бөлшек санға түрлендіріңіз.
print(float(15))
# Out:
# 15.0

# %%
# 16-тапсырма: `price = "500"` (мәтін) айнымалысын бүтін санға айналдырып, оған 100-ді қосып шығарыңыз.
price = "500"
print(int(price)+100)
# Out:
# 600

# %%
# 17-тапсырма: `age = 25` санын мәтінге (`str()`) айналдырыңыз.
age = 25
print(str(age))
# Out:
# 25

# %%
# 18-тапсырма: 15 пен 4-тің көбейтіндісін шығарыңыз.
print(15*4)
# Out:
# 60

# %%
# 19-тапсырма: 20-ны 3-ке бөліп, қалдығын (`%`) табыңыз.
print (20%3)
# Out:
# 2

# %%
# 20-тапсырма: 2-нің 5 дәрежесін (`**`) есептеңіз.
print(2**5)
# Out:
# 32

# %%
# 21-тапсырма: 10 мен 3-ті бүтін бөлу (`//`) арқылы есептеп шығарыңыз.
print(10//3)
# Out:
# 3

# %%
# 22-тапсырма: `num1 = 10` және `num2 = 3.5`. Осы екеуінің қосындысы қандай типке жататынын тексеріңіз.
num1= 10
num2 = 3.5
print(type(num1+num2))
# Out:
# <class 'float'>

# %%
# 23-тапсырма: 0 санын логикалық типке (`bool()`) түрлендіріңіз. Нәтиже қандай болды?
print(bool(0))
# Out:
# False

# %%
# 24-тапсырма: Кез келген бос емес мәтінді логикалық типке (`bool()`) түрлендіріңіз.
print(bool("smosk"))
# Out:
# True

# %%
# 25-тапсырма: Төмендегі математикалық өрнектің нәтижесін шығарыңыз: (10 + 5) * 2
print((10 + 5) * 2)
# Out:
# 30

# %% [markdown]
# ## 3-бөлім: Жолдар (Strings) - Мәтінмен жұмыс (26-40 тапсырмалар)
#
# Мәтіндерді кесу, ұзындығын табу және арнайы әдістерді (`upper`, `lower`, `replace`) қолдануды үйренеміз.

# %%
# 26-тапсырма: `word = "Python"` айнымалысының ұзындығын (`len()`) табыңыз.
word = "Python"
len(word)
# Out:
# 6

# %%
# 27-тапсырма: `word` мәтінінің бірінші әрпін (индекс 0) шығарыңыз.
soz = "word"
print(soz[0])

# %%
# 28-тапсырма: `word` мәтінінің соңғы әрпін (индекс -1) шығарыңыз.
soz = "word"
print(soz[-1])
# Out:
# d

# %%
# 29-тапсырма: "Kazakhstan" сөзінен алғашқы 6 әріпті кесіп алыңыз (Slicing).
word = "Kazakhstan"
print(word[6:])
# Out:
# stan

# %%
# 30-тапсырма: "hello" сөзін толығымен бас әріптермен (`upper()`) шығарыңыз.
word = "hello"
print(word.upper())
# Out:
# HELLO

# %%
# 31-тапсырма: "WORLD" сөзін толығымен кіші әріптермен (`lower()`) шығарыңыз.
word = "WORLD"
print(word.lower())
# Out:
# world

# %%
# 32-тапсырма: `part1 = "Data"` және `part2 = "Science"` сөздерін бос орын арқылы біріктіріңіз.
part1 = "Data"
part2 = "Science"
print(part1 + " "+  part2)
# Out:
# Data Science

# %%
# 33-тапсырма: "  Сәлем  " мәтінінің шеттеріндегі бос орындарды (`strip()`) алып тастап шығарыңыз.
word = "   Salem "
print(word.strip())
# Out:
# Salem

# %%
# 34-тапсырма: "Apple" сөзіндегі "p" әріптерін "b" әрпіне ауыстырыңыз (`replace()`).
print("Apple".replace("p", "b"))
# Out:
# Abble

# %%
# 35-тапсырма: Мәтіннің ішінде "a" әрпі неше рет кездесетінін табыңыз: "banana". (`count()`)
print("banana".count("a"))
# Out:
# 3

# %%
# 36-тапсырма: f-string көмегімен айнымалыларды мәтінге қосыңыз: name = "Ali", age = 20. Нәтиже: "Ali is 20 years old"
name = "Ali"
age = 20
print(f"{name} is {age} years old")
# Out:
# Ali is 20 years old

# %%
# 37-тапсырма: "Алматы" сөзін керісінше жазып шығарыңыз. (Кеңес: [::-1])
print("Almaty"[::-1])
# Out:
# ytamlA

# %%
# 38-тапсырма: "Programming" сөзінде "gram" сөзі бар екенін тексеріңіз (`in` кілт сөзі).
if "gram" in "Programming":
    print("Yes, 'gram' is in the word")
else:
    print("No, 'gram' is not in the word")
# Out:
# Yes, 'gram' is in the word

# %%
# 39-тапсырма: "Python is awesome" сөзін бос орындар арқылы тізімге бөліңіз (`split()`).
print("Python is awesome".split())
# Out:
# ['Python', 'is', 'awesome']

# %%
# 40-тапсырма: `str()` функциясын пайдаланып 2024 санын мәтінге айналдырып, оған " жыл" сөзін қосып шығарыңыз.
print(str(2024) + " year")
# Out:
# 2024 year

# %% [markdown]
# ## 4-бөлім: Логика және Шартты операторлар (If, Elif, Else) (41-50 тапсырмалар)
#
# Бағдарламаның логикасын құрып, белгілі бір шарттарға байланысты әртүрлі шешімдер қабылдаймыз.

# %%
# 41-тапсырма: 10 мен 5-ті салыстырыңыз (10 > 5). Нәтижесін шығарыңыз.
print(10 > 5)
# Out:
# True

# %%
# 42-тапсырма: 15 пен 15-тің тең екенін тексеріңіз (`==`).
if (15 == 15):
  print("egual")
else:
  print("not equal")
# Out:
# egual

# %%
# 43-тапсырма: `x = 10`. Егер `x > 5` болса, "Үлкен" деп шығаратын шарт жазыңыз.
x = 10
if x > 5:
  print ("x is bigger")
# Out:
# x is bigger

# %%
# 44-тапсырма: `num = 4`. `if-else` арқылы бұл санның жұп немесе тақ екенін тексеріп шығарыңыз (қалдық `% 2 == 0` болуы керек).
num = 4
if (num % 2 ==0):
  print("even")
else:
  print("odd")
# Out:
# even

# %%
# 45-тапсырма: `a = 15`, `b = 20`. Қайсысы үлкен екенін `if...else` арқылы табыңыз.
a = 15
b = 20
if (a > b):
  print ( a )
else:
  print (b )
# Out:
# 20

# %%
# 46-тапсырма: `score = 75`. Егер баға >= 90 болса "A", >= 80 болса "B", >= 70 болса "C", әйтпесе "D" деп шығаратын код жазыңыз (`if...elif...else`).
score = 75
if (score >= 90):
  print("A")
elif (score >= 80):
  print("B")
elif (score >= 70):
  print("C")
else:
  print("D")
# Out:
# C

# %%
# 47-тапсырма: `password = "secret123"`. Егер password дәл осы мәнге тең болса "Қосылды", әйтпесе "Қате құпия сөз" деп шығарыңыз.
password = "secret123"
if (password == "password"):
  print("Қосылды")
else:
  print("Қате құпия сөз")
# Out:
# Қате құпия сөз

# %%
# 48-тапсырма: `age = 16`. 18-ге толғанын тексеріңіз. Егер толмаса, кәмелетке толуға қанша жыл қалғанын есептеп шығарыңыз.
age = 16
if age >= 18:
  print("OK")
else:
  print(18 - age)
# Out:
# 2

# %%
# 49-тапсырма: Логикалық `and` қолдану: `x = 7`. Егер x > 0 ЖӘНЕ x < 10 болса "Бір таңбалы оң сан" деп шығарыңыз.
x = 7
if(x > 0 and x < 10):
  print("Бір таңбалы оң сан")
else:
  print("Бір таңбалы сан емес")
# Out:
# Бір таңбалы оң сан

# %%
# 50-тапсырма: Логикалық `or` қолдану: `day = "Сенбі"`. Егер day "Сенбі" НЕМЕСЕ "Жексенбі" болса, "Бүгін демалыс" деп шығарыңыз.
day = "Сенбі"
if (day == "Сенбі" or "Жексенбі"):
  print("Бүгін демалыс")
else:
  print("Бүгін демалыс емес")
# Out:
# Бүгін демалыс
