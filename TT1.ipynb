# %% [markdown]
# <a href="https://colab.research.google.com/github/smtmn0/AminaS/blob/main/TT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, user")
# Out:
# Hello, user

# %%
a_side = 9
b_side = 12
c_side = 10

if (a_side + b_side > c_side) and (a_side + c_side > b_side) and (b_side + c_side > a_side):
    print("Valid")
else:
    print("Invalid")
# Out:
# Valid

# %%
for i in range(5):
    print("Bye")
# Out:
# Bye
# Bye
# Bye
# Bye
# Bye
